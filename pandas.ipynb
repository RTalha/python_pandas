# %%
import pandas as pd

# %%
df= pd.read_csv('/home/talha/Documents/weather.csv',parse_dates='date')

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 18  1/19/2016           22         3        42                 30.03
# 19  1/20/2016           32        15        49                 30.13
# 20  1/21/2016           31        11        45                 30.15
# 21  1/22/2016           26         6        41                 30.21
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 24  1/25/2016           34        18        54                 30.25
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 0                10           8.0               0           5       NaN
# 1                10           7.0               0           3       NaN
# 2                10           8.0               0           1       NaN
# 3                10           9.0               0           3       NaN
# 4                10           5.0               0           0       NaN
# 5                10           4.0               0           0       NaN
# 6                10           2.0               0           3       NaN
# 7                10           4.0               0           8       NaN
# 8                 9           8.0               T           8      Rain
# 9                 4           NaN             1.8           7      Rain
# 10               10           NaN               0           1       NaN
# 11               10           6.0               T           4       NaN
# 12               10          10.0               0           0       NaN
# 13               10           5.0               T           7       NaN
# 14                9           5.0               T           2       NaN
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# 17                9          12.0               T           2      Snow
# 18               10          11.0               0           1       NaN
# 19               10           6.0               0           2       NaN
# 20               10           6.0               0           1       NaN
# 21                9           NaN            0.01           3      Snow
# 22                1          16.0            2.31           8  Fog-Snow
# 23                8           6.0               T           3      Snow
# 24               10           3.0               0           2       NaN
# 25               10           7.0               0           2       NaN
# 26               10           7.0               T           3      Rain
# 27               10           5.0               0           1       NaN
# 28               10           8.0               0           4       NaN
# 29               10           7.0               0           0       NaN
# 30               10           5.0               0           0       NaN
#
#     WindDirDegrees
# 0              281
# 1              275
# 2              277
# 3              345
# 4              333
# 5              259
# 6              293
# 7               79
# 8               76
# 9              109
# 10             289
# 11             235
# 12             284
# 13             266
# 14             101
# 15             340
# 16             345
# 17             293
# 18             293
# 19             302
# 20             312
# 21              34
# 22              42
# 23             327
# 24             286
# 25             244
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
df['WindSpeedMPH'].mean()
#it will find mean of WindSpeedMPH colums only
# Out:
# 6.892857142857143

# %%
df['WindSpeedMPH'].max()
# Out:
# 16.0

# %%
df['WindSpeedMPH'][df['Events']=='Rain']
# Out:
# 8     8.0
# 9     NaN
# 15    7.0
# 26    7.0
# Name: WindSpeedMPH, dtype: float64

# %%
df.dtypes
#df.WindSpeedMPH.dtype
# Out:
# EST                      object
# Temperature               int64
# DewPoint                  int64
# Humidity                  int64
# Sea Level PressureIn    float64
# VisibilityMiles           int64
# WindSpeedMPH            float64
# PrecipitationIn          object
# CloudCover                int64
# Events                   object
# WindDirDegrees            int64
# dtype: object

# %%
df.count()
# Out:
# EST                     31
# Temperature             31
# DewPoint                31
# Humidity                31
# Sea Level PressureIn    31
# VisibilityMiles         31
# WindSpeedMPH            28
# PrecipitationIn         31
# CloudCover              31
# Events                   9
# WindDirDegrees          31
# dtype: int64

# %%
#df[['WindSpeedMPH','DewPoint']].agg(['sum','min','max'])
df.agg(['sum','min','max'])
# Out:
#                                                    EST  Temperature  DewPoint  \
# max                                           1/9/2016           50        46
# min                                           1/1/2016           20        -3
# sum  1/1/20161/2/20161/3/20161/4/20161/5/20161/6/20...         1075       553
#
#      Humidity  Sea Level PressureIn  VisibilityMiles  WindSpeedMPH  \
# max        78                 30.57               10          16.0
# min        33                 29.52                1           2.0
# sum      1602                929.78              285         193.0
#
#                                    PrecipitationIn  CloudCover Events  \
# max                                              T           8   Snow
# min                                              0           0    inf
# sum  00000000T1.80T0TT0.240.05T0000.012.31T00T0000          97    NaN
#
#      WindDirDegrees
# max             345
# min              34
# sum            7661

# %%
rows,columns= df.shape

# %%
rows
# Out:
# 31

# %%
columns
# Out:
# 11

# %%
df.head()
#it prints first five rows
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
df.head(2)
#it prints first two rows
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
#
#    WindDirDegrees
# 0             281
# 1             275

# %%
df.tail()
#it prints last 5 rows
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
# 27               10           5.0               0           1    NaN
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
df.columns
#it will give you the title colums
# Out:
# Index([u'EST', u'Temperature', u'DewPoint', u'Humidity',
#        u'Sea Level PressureIn', u'VisibilityMiles', u'WindSpeedMPH',
#        u'PrecipitationIn', u'CloudCover', u'Events', u'WindDirDegrees'],
#       dtype='object')

# %%
df[2:5]#['WindSpeedMPH']
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 2             277
# 3             345
# 4             333

# %%
### df.EST #IT IS SAME AS df['EST'] WHICH IN BELOW

# %%
df['EST']
#df.EST
# Out:
# 0      1/1/2016
# 1      1/2/2016
# 2      1/3/2016
# 3      1/4/2016
# 4      1/5/2016
# 5      1/6/2016
# 6      1/7/2016
# 7      1/8/2016
# 8      1/9/2016
# 9     1/10/2016
# 10    1/11/2016
# 11    1/12/2016
# 12    1/13/2016
# 13    1/14/2016
# 14    1/15/2016
# 15    1/16/2016
# 16    1/17/2016
# 17    1/18/2016
# 18    1/19/2016
# 19    1/20/2016
# 20    1/21/2016
# 21    1/22/2016
# 22    1/23/2016
# 23    1/24/2016
# 24    1/25/2016
# 25    1/26/2016
# 26    1/27/2016
# 27    1/28/2016
# 28    1/29/2016
# 29    1/30/2016
# 30    1/31/2016
# Name: EST, dtype: object

# %%
df[['Events','EST']]  #for multiple colums
# Out:
#       Events        EST
# 0        NaN   1/1/2016
# 1        NaN   1/2/2016
# 2        NaN   1/3/2016
# 3        NaN   1/4/2016
# 4        NaN   1/5/2016
# 5        NaN   1/6/2016
# 6        NaN   1/7/2016
# 7        NaN   1/8/2016
# 8       Rain   1/9/2016
# 9       Rain  1/10/2016
# 10       NaN  1/11/2016
# 11       NaN  1/12/2016
# 12       NaN  1/13/2016
# 13       NaN  1/14/2016
# 14       NaN  1/15/2016
# 15      Rain  1/16/2016
# 16  Fog-Snow  1/17/2016
# 17      Snow  1/18/2016
# 18       NaN  1/19/2016
# 19       NaN  1/20/2016
# 20       NaN  1/21/2016
# 21      Snow  1/22/2016
# 22  Fog-Snow  1/23/2016
# 23      Snow  1/24/2016
# 24       NaN  1/25/2016
# 25       NaN  1/26/2016
# 26      Rain  1/27/2016
# 27       NaN  1/28/2016
# 28       NaN  1/29/2016
# 29       NaN  1/30/2016
# 30       NaN  1/31/2016

# %%
df.describe()
#it will give all statestic information
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# 50%          10.000000      6.500000    3.000000      281.000000
# 75%          10.000000      8.000000    4.500000      300.000000
# max          10.000000     16.000000    8.000000      345.000000

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 18  1/19/2016           22         3        42                 30.03
# 19  1/20/2016           32        15        49                 30.13
# 20  1/21/2016           31        11        45                 30.15
# 21  1/22/2016           26         6        41                 30.21
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 24  1/25/2016           34        18        54                 30.25
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 0                10           8.0               0           5       NaN
# 1                10           7.0               0           3       NaN
# 2                10           8.0               0           1       NaN
# 3                10           9.0               0           3       NaN
# 4                10           5.0               0           0       NaN
# 5                10           4.0               0           0       NaN
# 6                10           2.0               0           3       NaN
# 7                10           4.0               0           8       NaN
# 8                 9           8.0               T           8      Rain
# 9                 4           NaN             1.8           7      Rain
# 10               10           NaN               0           1       NaN
# 11               10           6.0               T           4       NaN
# 12               10          10.0               0           0       NaN
# 13               10           5.0               T           7       NaN
# 14                9           5.0               T           2       NaN
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# 17                9          12.0               T           2      Snow
# 18               10          11.0               0           1       NaN
# 19               10           6.0               0           2       NaN
# 20               10           6.0               0           1       NaN
# 21                9           NaN            0.01           3      Snow
# 22                1          16.0            2.31           8  Fog-Snow
# 23                8           6.0               T           3      Snow
# 24               10           3.0               0           2       NaN
# 25               10           7.0               0           2       NaN
# 26               10           7.0               T           3      Rain
# 27               10           5.0               0           1       NaN
# 28               10           8.0               0           4       NaN
# 29               10           7.0               0           0       NaN
# 30               10           5.0               0           0       NaN
#
#     WindDirDegrees
# 0              281
# 1              275
# 2              277
# 3              345
# 4              333
# 5              259
# 6              293
# 7               79
# 8               76
# 9              109
# 10             289
# 11             235
# 12             284
# 13             266
# 14             101
# 15             340
# 16             345
# 17             293
# 18             293
# 19             302
# 20             312
# 21              34
# 22              42
# 23             327
# 24             286
# 25             244
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
df.set_index('EST',inplace=True)
#inplace = true will set index in orignal data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-0b427d656f9c> in <module>()
# ----> 1 df.set_index('EST',inplace=True)
#       2 #inplace = true will set index in orignal data
#
# /home/talha/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in set_index(self, keys, drop, append, inplace, verify_integrity)
#    2926                 names.append(None)
#    2927             else:
# -> 2928                 level = frame[col]._values
#    2929                 names.append(col)
#    2930                 if drop:
#
# /home/talha/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# /home/talha/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# /home/talha/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1532         res = cache.get(item)
#    1533         if res is None:
# -> 1534             values = self._data.get(item)
#    1535             res = self._box_item_values(item, values)
#    1536             cache[item] = res
#
# /home/talha/anaconda2/lib/python2.7/site-packages/pandas/core/internals.pyc in get(self, item, fastpath)
#    3588
#    3589             if not isnull(item):
# -> 3590                 loc = self.items.get_loc(item)
#    3591             else:
#    3592                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /home/talha/anaconda2/lib/python2.7/site-packages/pandas/core/indexes/base.pyc in get_loc(self, key, method, tolerance)
#    2393                 return self._engine.get_loc(key)
#    2394             except KeyError:
# -> 2395                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2396
#    2397         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5239)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20405)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20359)()
#
# KeyError: 'EST'

# %%
df
# Out:
#            Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/1/2016            38        23        52                 30.03
# 1/2/2016            36        18        46                 30.02
# 1/3/2016            40        21        47                 29.86
# 1/4/2016            25         9        44                 30.05
# 1/5/2016            20        -3        41                 30.57
# 1/6/2016            33         4        35                 30.50
# 1/7/2016            39        11        33                 30.28
# 1/8/2016            39        29        64                 30.20
# 1/9/2016            44        38        77                 30.16
# 1/10/2016           50        46        71                 29.59
# 1/11/2016           33         8        37                 29.92
# 1/12/2016           35        15        53                 29.85
# 1/13/2016           26         4        42                 29.94
# 1/14/2016           30        12        47                 29.95
# 1/15/2016           43        31        62                 29.82
# 1/16/2016           47        37        70                 29.52
# 1/17/2016           36        23        66                 29.78
# 1/18/2016           25         6        53                 29.83
# 1/19/2016           22         3        42                 30.03
# 1/20/2016           32        15        49                 30.13
# 1/21/2016           31        11        45                 30.15
# 1/22/2016           26         6        41                 30.21
# 1/23/2016           26        21        78                 29.77
# 1/24/2016           28        11        53                 29.92
# 1/25/2016           34        18        54                 30.25
# 1/26/2016           43        29        56                 30.03
# 1/27/2016           41        22        45                 30.03
# 1/28/2016           37        20        51                 29.90
# 1/29/2016           36        21        50                 29.58
# 1/30/2016           34        16        46                 30.01
# 1/31/2016           46        28        52                 29.90
#
#            VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover  \
# EST
# 1/1/2016                10           8.0               0           5
# 1/2/2016                10           7.0               0           3
# 1/3/2016                10           8.0               0           1
# 1/4/2016                10           9.0               0           3
# 1/5/2016                10           5.0               0           0
# 1/6/2016                10           4.0               0           0
# 1/7/2016                10           2.0               0           3
# 1/8/2016                10           4.0               0           8
# 1/9/2016                 9           8.0               T           8
# 1/10/2016                4           NaN             1.8           7
# 1/11/2016               10           NaN               0           1
# 1/12/2016               10           6.0               T           4
# 1/13/2016               10          10.0               0           0
# 1/14/2016               10           5.0               T           7
# 1/15/2016                9           5.0               T           2
# 1/16/2016                8           7.0            0.24           7
# 1/17/2016                8           6.0            0.05           6
# 1/18/2016                9          12.0               T           2
# 1/19/2016               10          11.0               0           1
# 1/20/2016               10           6.0               0           2
# 1/21/2016               10           6.0               0           1
# 1/22/2016                9           NaN            0.01           3
# 1/23/2016                1          16.0            2.31           8
# 1/24/2016                8           6.0               T           3
# 1/25/2016               10           3.0               0           2
# 1/26/2016               10           7.0               0           2
# 1/27/2016               10           7.0               T           3
# 1/28/2016               10           5.0               0           1
# 1/29/2016               10           8.0               0           4
# 1/30/2016               10           7.0               0           0
# 1/31/2016               10           5.0               0           0
#
#              Events  WindDirDegrees
# EST
# 1/1/2016        NaN             281
# 1/2/2016        NaN             275
# 1/3/2016        NaN             277
# 1/4/2016        NaN             345
# 1/5/2016        NaN             333
# 1/6/2016        NaN             259
# 1/7/2016        NaN             293
# 1/8/2016        NaN              79
# 1/9/2016       Rain              76
# 1/10/2016      Rain             109
# 1/11/2016       NaN             289
# 1/12/2016       NaN             235
# 1/13/2016       NaN             284
# 1/14/2016       NaN             266
# 1/15/2016       NaN             101
# 1/16/2016      Rain             340
# 1/17/2016  Fog-Snow             345
# 1/18/2016      Snow             293
# 1/19/2016       NaN             293
# 1/20/2016       NaN             302
# 1/21/2016       NaN             312
# 1/22/2016      Snow              34
# 1/23/2016  Fog-Snow              42
# 1/24/2016      Snow             327
# 1/25/2016       NaN             286
# 1/26/2016       NaN             244
# 1/27/2016      Rain             311
# 1/28/2016       NaN             234
# 1/29/2016       NaN             298
# 1/30/2016       NaN             257
# 1/31/2016       NaN             241

# %%
df1
# Out:
#            Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 1/1/2016            38        23        52                 30.03
# 1/2/2016            36        18        46                 30.02
# 1/3/2016            40        21        47                 29.86
# 1/4/2016            25         9        44                 30.05
# 1/5/2016            20        -3        41                 30.57
# 1/6/2016            33         4        35                 30.50
# 1/7/2016            39        11        33                 30.28
# 1/8/2016            39        29        64                 30.20
# 1/9/2016            44        38        77                 30.16
# 1/10/2016           50        46        71                 29.59
# 1/11/2016           33         8        37                 29.92
# 1/12/2016           35        15        53                 29.85
# 1/13/2016           26         4        42                 29.94
# 1/14/2016           30        12        47                 29.95
# 1/15/2016           43        31        62                 29.82
# 1/16/2016           47        37        70                 29.52
# 1/17/2016           36        23        66                 29.78
# 1/18/2016           25         6        53                 29.83
# 1/19/2016           22         3        42                 30.03
# 1/20/2016           32        15        49                 30.13
# 1/21/2016           31        11        45                 30.15
# 1/22/2016           26         6        41                 30.21
# 1/23/2016           26        21        78                 29.77
# 1/24/2016           28        11        53                 29.92
# 1/25/2016           34        18        54                 30.25
# 1/26/2016           43        29        56                 30.03
# 1/27/2016           41        22        45                 30.03
# 1/28/2016           37        20        51                 29.90
# 1/29/2016           36        21        50                 29.58
# 1/30/2016           34        16        46                 30.01
# 1/31/2016           46        28        52                 29.90
#
#            VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover  \
# EST
# 1/1/2016                10           8.0               0           5
# 1/2/2016                10           7.0               0           3
# 1/3/2016                10           8.0               0           1
# 1/4/2016                10           9.0               0           3
# 1/5/2016                10           5.0               0           0
# 1/6/2016                10           4.0               0           0
# 1/7/2016                10           2.0               0           3
# 1/8/2016                10           4.0               0           8
# 1/9/2016                 9           8.0               T           8
# 1/10/2016                4           NaN             1.8           7
# 1/11/2016               10           NaN               0           1
# 1/12/2016               10           6.0               T           4
# 1/13/2016               10          10.0               0           0
# 1/14/2016               10           5.0               T           7
# 1/15/2016                9           5.0               T           2
# 1/16/2016                8           7.0            0.24           7
# 1/17/2016                8           6.0            0.05           6
# 1/18/2016                9          12.0               T           2
# 1/19/2016               10          11.0               0           1
# 1/20/2016               10           6.0               0           2
# 1/21/2016               10           6.0               0           1
# 1/22/2016                9           NaN            0.01           3
# 1/23/2016                1          16.0            2.31           8
# 1/24/2016                8           6.0               T           3
# 1/25/2016               10           3.0               0           2
# 1/26/2016               10           7.0               0           2
# 1/27/2016               10           7.0               T           3
# 1/28/2016               10           5.0               0           1
# 1/29/2016               10           8.0               0           4
# 1/30/2016               10           7.0               0           0
# 1/31/2016               10           5.0               0           0
#
#              Events  WindDirDegrees
# EST
# 1/1/2016        NaN             281
# 1/2/2016        NaN             275
# 1/3/2016        NaN             277
# 1/4/2016        NaN             345
# 1/5/2016        NaN             333
# 1/6/2016        NaN             259
# 1/7/2016        NaN             293
# 1/8/2016        NaN              79
# 1/9/2016       Rain              76
# 1/10/2016      Rain             109
# 1/11/2016       NaN             289
# 1/12/2016       NaN             235
# 1/13/2016       NaN             284
# 1/14/2016       NaN             266
# 1/15/2016       NaN             101
# 1/16/2016      Rain             340
# 1/17/2016  Fog-Snow             345
# 1/18/2016      Snow             293
# 1/19/2016       NaN             293
# 1/20/2016       NaN             302
# 1/21/2016       NaN             312
# 1/22/2016      Snow              34
# 1/23/2016  Fog-Snow              42
# 1/24/2016      Snow             327
# 1/25/2016       NaN             286
# 1/26/2016       NaN             244
# 1/27/2016      Rain             311
# 1/28/2016       NaN             234
# 1/29/2016       NaN             298
# 1/30/2016       NaN             257
# 1/31/2016       NaN             241

# %%
df.reset_index(inplace=True)

# %%
df1

# %%
df
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016           38        23        52                 30.03
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 16  1/17/2016           36        23        66                 29.78
# 17  1/18/2016           25         6        53                 29.83
# 18  1/19/2016           22         3        42                 30.03
# 19  1/20/2016           32        15        49                 30.13
# 20  1/21/2016           31        11        45                 30.15
# 21  1/22/2016           26         6        41                 30.21
# 22  1/23/2016           26        21        78                 29.77
# 23  1/24/2016           28        11        53                 29.92
# 24  1/25/2016           34        18        54                 30.25
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 27  1/28/2016           37        20        51                 29.90
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover    Events  \
# 0                10           8.0               0           5       NaN
# 1                10           7.0               0           3       NaN
# 2                10           8.0               0           1       NaN
# 3                10           9.0               0           3       NaN
# 4                10           5.0               0           0       NaN
# 5                10           4.0               0           0       NaN
# 6                10           2.0               0           3       NaN
# 7                10           4.0               0           8       NaN
# 8                 9           8.0               T           8      Rain
# 9                 4           NaN             1.8           7      Rain
# 10               10           NaN               0           1       NaN
# 11               10           6.0               T           4       NaN
# 12               10          10.0               0           0       NaN
# 13               10           5.0               T           7       NaN
# 14                9           5.0               T           2       NaN
# 15                8           7.0            0.24           7      Rain
# 16                8           6.0            0.05           6  Fog-Snow
# 17                9          12.0               T           2      Snow
# 18               10          11.0               0           1       NaN
# 19               10           6.0               0           2       NaN
# 20               10           6.0               0           1       NaN
# 21                9           NaN            0.01           3      Snow
# 22                1          16.0            2.31           8  Fog-Snow
# 23                8           6.0               T           3      Snow
# 24               10           3.0               0           2       NaN
# 25               10           7.0               0           2       NaN
# 26               10           7.0               T           3      Rain
# 27               10           5.0               0           1       NaN
# 28               10           8.0               0           4       NaN
# 29               10           7.0               0           0       NaN
# 30               10           5.0               0           0       NaN
#
#     WindDirDegrees
# 0              281
# 1              275
# 2              277
# 3              345
# 4              333
# 5              259
# 6              293
# 7               79
# 8               76
# 9              109
# 10             289
# 11             235
# 12             284
# 13             266
# 14             101
# 15             340
# 16             345
# 17             293
# 18             293
# 19             302
# 20             312
# 21              34
# 22              42
# 23             327
# 24             286
# 25             244
# 26             311
# 27             234
# 28             298
# 29             257
# 30             241

# %%
df.loc[3:5]
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
# 5  1/6/2016           33         4        35                 30.50
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
# 5               10           4.0               0           0    NaN
#
#    WindDirDegrees
# 3             345
# 4             333
# 5             259

# %%
#now munging and ragling data for processing

import pandas as pd
df=pd.read_csv('/home/talha/Documents/stock_data.csv')

# %%
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df=pd.read_csv('/home/talha/Documents/stock_data.csv',skiprows=1)
df
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
df=pd.read_csv('/home/talha/Documents/stock_data.csv',index_col=2)
df
# Out:
#         tickers            eps price         people
# revenue
#  87       GOOGL          27.82   845     larry page
#  484        WMT           4.61    65           n.a.
#  85        MSFT             -1    64     bill gates
#  50        RIL   not available  1023  mukesh ambani
# -1         TATA            5.6  n.a.     ratan tata

# %%
#df=pd.read_csv('/home/talha/Documents/stock_data.csv',header=1,nrows=2)
df=pd.read_csv('/home/talha/Documents/stock_data.csv',header=1)
df

# %%
#it will add column names and heaer =0 mean skip the column name or skip first title row
#df=pd.read_csv('/home/talha/Documents/stock_data.csv',header=None,names=["A","B","C","D","E"],index_col=1)
df=pd.read_csv('/home/talha/Documents/stock_data.csv',header=None,names=["A","B","C","D","E"])
df
# Out:
#          A              B        C      D              E
# 0  tickers            eps  revenue  price         people
# 1    GOOGL          27.82       87    845     larry page
# 2      WMT           4.61      484     65           n.a.
# 3     MSFT             -1       85     64     bill gates
# 4     RIL   not available       50   1023  mukesh ambani
# 5     TATA            5.6       -1   n.a.     ratan tata

# %%
df=pd.read_csv('/home/talha/Documents/stock_data.csv',nrows=3,header=1,index_col=1,names=["A","B","C","D","E"])
df
# Out:
#                   A    C     D              E
# B
# 4.61            WMT  484    65           n.a.
# -1             MSFT   85    64     bill gates
# not available  RIL    50  1023  mukesh ambani

# %%
df=pd.read_csv('/home/talha/Documents/stock_data.csv',header=None,index_col=1,na_values=["n.a.","not available",-1])
df
# Out:
#              0        2      3              4
# 1
# eps    tickers  revenue  price         people
# 27.82    GOOGL       87    845     larry page
# 4.61       WMT      484     65            NaN
# NaN       MSFT       85     64     bill gates
# NaN       RIL        50   1023  mukesh ambani
# 5.6       TATA      NaN    NaN     ratan tata

# %%
df=pd.read_csv('/home/talha/Documents/stock_data.csv',na_values={
    'eps':['not available'],
    'revenue':[-1],
    'price':['n.a.'],
    'people':['n.a.','not available']
})
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82     87.0   845.0     larry page
# 1     WMT   4.61    484.0    65.0            NaN
# 2    MSFT  -1.00     85.0    64.0     bill gates
# 3    RIL     NaN     50.0  1023.0  mukesh ambani
# 4    TATA   5.60      NaN     NaN     ratan tata

# %%
df.to_csv('/home/talha/Documents/update_stock_data.csv',index=False)

# %%
df.columns
# Out:
# Index([u'tickers', u'eps', u'revenue', u'price', u'people'], dtype='object')

# %%
df.to_csv('/home/talha/Documents/update_stock_data.csv',columns=['eps','revenue'],index=False)
