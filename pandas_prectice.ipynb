# %%
import pandas as pd

# %%
df=pd.read_csv('/home/talha/Downloads/AAPL.csv',parse_dates=["Date"])
df.set_index("Date",inplace=True)
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-10-01  227.949997  229.419998  226.350006  227.259995  227.259995
# 2018-10-02  227.250000  230.000000  226.630005  229.279999  229.279999
# 2018-10-03  230.050003  233.470001  229.779999  232.070007  232.070007
# 2018-10-04  230.779999  232.350006  226.729996  227.990005  227.990005
# 2018-10-05  227.960007  228.410004  220.580002  224.289993  224.289993
# 2018-10-08  222.210007  224.800003  220.199997  223.770004  223.770004
# 2018-10-09  223.639999  227.270004  222.250000  226.869995  226.869995
# 2018-10-10  225.460007  226.350006  216.050003  216.360001  216.360001
# 2018-10-11  214.520004  219.500000  212.320007  214.449997  214.449997
# 2018-10-12  220.419998  222.880005  216.839996  222.110001  222.110001
# 2018-10-15  221.160004  221.830002  217.270004  217.360001  217.360001
# 2018-10-16  218.929993  222.990005  216.759995  222.149994  222.149994
# ...

# %%
df.index
# Out:
# DatetimeIndex(['2018-10-01', '2018-10-02', '2018-10-03', '2018-10-04',
#                '2018-10-05', '2018-10-08', '2018-10-09', '2018-10-10',
#                '2018-10-11', '2018-10-12', '2018-10-15', '2018-10-16',
#                '2018-10-17', '2018-10-18', '2018-10-19', '2018-10-22',
#                '2018-10-23', '2018-10-24', '2018-10-25', '2018-10-26',
#                '2018-10-29'],
#               dtype='datetime64[ns]', name=u'Date', freq=None)

# %%
type(df.Date[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-aaea4137d6da> in <module>()
# ----> 1 type(df.Date[0])
#
# /home/talha/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Date'

# %%
df["2018-10"].Close.mean()
# Out:
# 221.51047552380953

# %%
# %matplotlib inline
df.Close.resample('W').plot()
# Out:
# /home/talha/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:2: FutureWarning:
# .resample() is now a deferred operation
# You called plot(...) on this deferred object which materialized it into a series
# by implicitly taking the mean.  Use .resample(...).mean() instead

# %%
df["2018-10-01":"2018-10-10"]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-10-01  227.949997  229.419998  226.350006  227.259995  227.259995
# 2018-10-02  227.250000  230.000000  226.630005  229.279999  229.279999
# 2018-10-03  230.050003  233.470001  229.779999  232.070007  232.070007
# 2018-10-04  230.779999  232.350006  226.729996  227.990005  227.990005
# 2018-10-05  227.960007  228.410004  220.580002  224.289993  224.289993
# 2018-10-08  222.210007  224.800003  220.199997  223.770004  223.770004
# 2018-10-09  223.639999  227.270004  222.250000  226.869995  226.869995
# 2018-10-10  225.460007  226.350006  216.050003  216.360001  216.360001
#
#               Volume
# Date
# 2018-10-01  23600800
# 2018-10-02  24788200
# 2018-10-03  28654800
# 2018-10-04  32042000
# 2018-10-05  33580500
# 2018-10-08  29663900
# 2018-10-09  26891000
# 2018-10-10  41990600
